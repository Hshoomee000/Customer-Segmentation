# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
surc_train =r"C:\Users\hawra\OneDrive\Desktop\project\Macine Learingn\session 5\unsopervised\task\Train.csv"
data_train = pd.read_csv(surc_train)
data_train
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
data_train.duplicated().sum()
# Out:
# 0

# %%
data_train.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
data_train =data_train.dropna()
data_train
# Out:
#           ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0     462809    Male           No   22        No  Healthcare              1.0
# 2     466315  Female          Yes   67       Yes    Engineer              1.0
# 3     461735    Male          Yes   67       Yes      Lawyer              0.0
# 5     461319    Male          Yes   56        No      Artist              0.0
# 6     460156    Male           No   32       Yes  Healthcare              1.0
# ...      ...     ...          ...  ...       ...         ...              ...
# 8062  463002    Male          Yes   41       Yes      Artist              0.0
# 8064  464685    Male           No   35        No   Executive              3.0
# 8065  465406  Female           No   33       Yes  Healthcare              1.0
# 8066  467299  Female           No   27       Yes  Healthcare              1.0
# 8067  461879    Male          Yes   37       Yes   Executive              0.0
#
# ...

# %%
data_train.isnull().sum()
# Out:
# ID                 0
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# Segmentation       0
# dtype: int64

# %%
data_train.shape
# Out:
# (6665, 11)

# %%
data_train1 = data_train.drop('ID' , axis='columns')

# %%
data_train1
# Out:
#       Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0       Male           No   22        No  Healthcare              1.0
# 2     Female          Yes   67       Yes    Engineer              1.0
# 3       Male          Yes   67       Yes      Lawyer              0.0
# 5       Male          Yes   56        No      Artist              0.0
# 6       Male           No   32       Yes  Healthcare              1.0
# ...      ...          ...  ...       ...         ...              ...
# 8062    Male          Yes   41       Yes      Artist              0.0
# 8064    Male           No   35        No   Executive              3.0
# 8065  Female           No   33       Yes  Healthcare              1.0
# 8066  Female           No   27       Yes  Healthcare              1.0
# 8067    Male          Yes   37       Yes   Executive              0.0
#
#      Spending_Score  Family_Size  Var_1 Segmentation
# 0               Low          4.0  Cat_4            D
# ...

# %%
data_train=data_train1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lp = LabelEncoder()
lp.fit(data_train['Gender'])
data_train['Gender'] = lp.fit_transform(data_train['Gender'])
data_train
# Out:
#       Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0          1           No   22        No  Healthcare              1.0
# 2          0          Yes   67       Yes    Engineer              1.0
# 3          1          Yes   67       Yes      Lawyer              0.0
# 5          1          Yes   56        No      Artist              0.0
# 6          1           No   32       Yes  Healthcare              1.0
# ...      ...          ...  ...       ...         ...              ...
# 8062       1          Yes   41       Yes      Artist              0.0
# 8064       1           No   35        No   Executive              3.0
# 8065       0           No   33       Yes  Healthcare              1.0
# 8066       0           No   27       Yes  Healthcare              1.0
# 8067       1          Yes   37       Yes   Executive              0.0
#
#      Spending_Score  Family_Size  Var_1 Segmentation
# 0               Low          4.0  Cat_4            D
# ...

# %%
data_train['Ever_Married'] = lp.fit_transform(data_train['Ever_Married'])
data_train
# Out:
#       Gender  Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0          1             0   22        No  Healthcare              1.0
# 2          0             1   67       Yes    Engineer              1.0
# 3          1             1   67       Yes      Lawyer              0.0
# 5          1             1   56        No      Artist              0.0
# 6          1             0   32       Yes  Healthcare              1.0
# ...      ...           ...  ...       ...         ...              ...
# 8062       1             1   41       Yes      Artist              0.0
# 8064       1             0   35        No   Executive              3.0
# 8065       0             0   33       Yes  Healthcare              1.0
# 8066       0             0   27       Yes  Healthcare              1.0
# 8067       1             1   37       Yes   Executive              0.0
#
#      Spending_Score  Family_Size  Var_1 Segmentation
# 0               Low          4.0  Cat_4            D
# ...

# %%
data_train['Graduated']= lp.fit_transform(data_train['Graduated']) 
data_train['Spending_Score'] = lp.fit_transform(data_train['Spending_Score'])
data_train['Family_Size'] = lp.fit_transform(data_train['Family_Size'])
data_train['Var_1'] = lp.fit_transform(data_train['Var_1'])
data_train['Profession'] = lp.fit_transform(data_train['Profession'])
data_train
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           5              1.0
# 2          0             1   67          1           2              1.0
# 3          1             1   67          1           7              0.0
# 5          1             1   56          0           0              0.0
# 6          1             0   32          1           5              1.0
# ...      ...           ...  ...        ...         ...              ...
# 8062       1             1   41          1           0              0.0
# 8064       1             0   35          0           4              3.0
# 8065       0             0   33          1           5              1.0
# 8066       0             0   27          1           5              1.0
# 8067       1             1   37          1           4              0.0
#
#       Spending_Score  Family_Size  Var_1 Segmentation
# ...

# %%
data_train['Segmentation'].unique()
# Out:
# array(['D', 'B', 'C', 'A'], dtype=object)

# %%
data_train['Segmentation'] = data_train['Segmentation'].map({'A':1 , 'B':2 ,'C':3 , 'D':4 })
data_train
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           5              1.0
# 2          0             1   67          1           2              1.0
# 3          1             1   67          1           7              0.0
# 5          1             1   56          0           0              0.0
# 6          1             0   32          1           5              1.0
# ...      ...           ...  ...        ...         ...              ...
# 8062       1             1   41          1           0              0.0
# 8064       1             0   35          0           4              3.0
# 8065       0             0   33          1           5              1.0
# 8066       0             0   27          1           5              1.0
# 8067       1             1   37          1           4              0.0
#
#       Spending_Score  Family_Size  Var_1  Segmentation
# ...

# %%
X = data_train.drop(['Segmentation'], axis=1)
y = data_train['Segmentation']

# %%
y = y.to_frame()

# %%
y = y.reset_index()

# %%
print (X.shape ,"    " , y.shape)
# Out:
# (6665, 9)      (6665, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = scaler.fit_transform(X)

# %% [markdown]
# # apply PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)
X_pca
# Out:
# array([[ 2.49461159,  1.29046807,  0.24858663],
#        [-1.44002096, -1.3978239 ,  1.17290204],
#        [-1.55747144,  0.59712601,  2.02673103],
#        ...,
#        [ 0.95068173, -1.64718799,  1.05209214],
#        [ 1.50585864, -0.56386692,  0.22138517],
#        [-1.09754659,  1.3591099 , -0.49035525]])

# %%
print("Original shape: {}".format(str(X.shape)))
print("Reduced shape: {}".format(str(X_pca.shape)))
print("Reduced shape: {}".format(str(y.shape)))
# Out:
# Original shape: (6665, 9)
# Reduced shape: (6665, 3)
# Reduced shape: (6665, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y,test_size=0.20, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_prid = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accurcy = accuracy_score(y_test ,y_prid)
print (accurcy)
# Out:
# 0.45461365341335336

# %%
from sklearn.svm import SVC 
svc = SVC()
svc.fit(X_train , y_train)
# Out:
# SVC()

# %%
y_prid = svc.predict(X_test)
accurcy = accuracy_score(y_test ,y_prid)
print (accurcy)
# Out:
# 0.49362340585146286

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=8 , random_state=0)

# %%
rf.fit(X_train , y_train)
# Out:
# RandomForestClassifier(max_depth=8, random_state=0)

# %%
y_prid = rf.predict(X_test)
accurcy = accuracy_score(y_test ,y_prid)
print (accurcy)
# Out:
# 0.495873968492123

# %%
import seaborn as sns

# %%
sns.countplot(data = data_train , x= y)
# Out:
# <Axes: xlabel='Segmentation', ylabel='count'>

# %%
sns.boxplot(X_pca, fliersize=5)
# Out:
# <Axes: >

# %%
#X_pca contain all fetuers and y contain labels

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5 ,random_state=0)
kmeans.fit(X_pca)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
y_prid = kmeans.predict(X_pca)
accurcy = accuracy_score(y ,y_prid)
print (accurcy)
# Out:
# 0.2213053263315829

# %%
#so bad results

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score (X_pca,y_prid)
score
# Out:
# 0.3163815872340868

# %%
#the score <50 thin a results also bad :(

# %%
cs = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X_pca)
    cs.append(kmeans.inertia_)
plt.plot(range(1, 11), cs)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('CS')
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4 ,random_state=0)
kmeans.fit(X_pca)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
y_prid = kmeans.predict(X_pca)
accurcy = accuracy_score(y ,y_prid)
print (accurcy)
# Out:
# 0.12573143285821456

# %%
score = silhouette_score (X_pca,y_prid)
score
# Out:
# 0.36700096378042957

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_prid, s=60, cmap='Paired')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=60, marker='^', c=range(kmeans.n_clusters))
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
print("Cluster memberships:\n{}".format(y_prid))
# Out:
# Cluster memberships:
# [1 2 2 ... 3 1 0]

# %%
from sklearn.cluster import DBSCAN
dn = DBSCAN(eps=0.01)
y_prid=dn.fit_predict(X_pca)

# %%
accurcy = accuracy_score(y ,y_prid)
print (accurcy)
# Out:
# 0.000900225056264066

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=4)
y_prid = agg.fit_predict(X_pca)

# %%
accurcy = accuracy_score(y ,y_prid)
print (accurcy)
# Out:
# 0.12123030757689422
